# %% [markdown]
# # Guppy Demo
#
# This notebook gives a brief introduction to Guppy.
#
# Make sure that you have installed Guppy via `pip install guppylang`.

# %%
import guppylang
from guppylang import guppy


from guppylang.std.quantum import qubit, measure, h, cx
# Out:
# ciaociao
# ciaociao, I am in the struct decorator
# <class 'guppylang.std.iter.Range'>
# ciaociao, I am in the struct decorator
# <class 'guppylang.std.array.ArrayIter'>
# ciaociao, I am in the struct decorator
# <class 'guppylang.std.array.FrozenarrayIter'>
# ciaociao, I am in the struct decorator
# <class 'guppylang.std.angles.angle'>

# %%
@guppy.struct
class Name:
    text: str

@guppy.struct
class QubitPair:
    q1: int
    q2: int
    name: str

    @guppy
    def method(self: "QubitPair") -> None:
        self.q1 + 1


print("§§§§§§")
QubitPair.check()
# Out:
# ciaociao, I am in the struct decorator
# <class '__main__.Name'>
# ciaociao, I am in the struct decorator
# <class '__main__.QubitPair'>
# §§§§§§
# ciaociao Checking definition DefId(id=327)
# ciaociao I'm parsing struct  QubitPair
# ClassDef(name='QubitPair', bases=[], keywords=[], body=[AnnAssign(target=Name(id='q1', ctx=Store(...)), annotation=Name(id='int', ctx=Load(...)), value=None, simple=1), ..., FunctionDef(name='method', args=arguments(posonlyargs=[], args=[arg(...)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Expr(value=BinOp(...))], decorator_list=[Name(id='guppy', ctx=Load(...))], returns=Constant(value=None, kind=None), type_comment=None, type_params=[])], decorator_list=[Attribute(value=Name(id='guppy', ctx=Load(...)), attr='struct', ctx=Load())], type_params=[])
# ciaociao I'm checking struct QubitPair
# ...

# %%
@guppy
def make_struct() -> QubitPair:
    # a,b = qubit(), qubit()
    # pair = QubitPair(1, 2, "my_pair")
    # pair.method()
    return QubitPair(1, 2, "my_pair")



program = make_struct.compile()
# Out:
# ciaociao I'm parsing struct  QubitPair
# ClassDef(name='QubitPair', bases=[], keywords=[], body=[AnnAssign(target=Name(id='q1', ctx=Store(...)), annotation=Name(id='int', ctx=Load(...)), value=None, simple=1), ..., FunctionDef(name='method', args=arguments(posonlyargs=[], args=[arg(...)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Expr(value=BinOp(...))], decorator_list=[Name(id='guppy', ctx=Load(...))], returns=Constant(value=None, kind=None), type_comment=None, type_params=[])], decorator_list=[Attribute(value=Name(id='guppy', ctx=Load(...)), attr='struct', ctx=Load())], type_params=[])
# ciaociao I'm checking (inside ParsedStructDef) struct instantiation QubitPair
# ciaociao I'm checking struct QubitPair
# ...

# %%
@guppy.enum
class MyEnum:
    Variant1 = {"a": int, "c": str}
    Variant2 = {"a": int, "b": str}


MyEnum.compile()
# Out:
# ciaociao I am in the enum decorator
# <class '__main__.MyEnum'>
# ciaociao I'm parsing enum
# ClassDef(name='MyEnum', bases=[], keywords=[], body=[Assign(targets=[Name(id='Variant1', ctx=Store(...))], value=Dict(keys=[Constant(...), Constant(...)], values=[Name(...), Name(...)]), type_comment=None), Assign(targets=[Name(id='Variant2', ctx=Store(...))], value=Dict(keys=[Constant(...), Constant(...)], values=[Name(...), Name(...)]), type_comment=None)], decorator_list=[Attribute(value=Name(id='guppy', ctx=Load(...)), attr='enum', ctx=Load())], type_params=[])
# ciaociao I'm checking enum MyEnum
# ciaociao variants:
# EnumVariant(name='Variant1', fields=[EnumVariantField(name='a', ty=NumericType(kind=<Kind.Int: 2>)), EnumVariantField(name='c', ty=OpaqueType(args=[], defn=OpaqueTypeDef(id=DefId(id=8), name='str', defined_at=None, description='type', params=[], never_copyable=False, never_droppable=False, to_hugr=<function <lambda> at 0x129bcefb0>, bound=None)))])
# ...

# %%
import ast

# print(ast.dump(ast.parse('{"x": int, 2: bool}'), indent=2))
print(ast.dump(ast.parse('a: type'), indent=2))
a = ast.parse('{"x": int, 2: bool}').body[0].value
print(ast.dump(a, indent=2))
print(type(a.keys[0].value), a.keys[0].value)
print(a.values[0])
print(type(a.keys[1].value), a.keys[1].value)
# Out:
# Module(
#   body=[
#     AnnAssign(
#       target=Name(id='a', ctx=Store()),
#       annotation=Name(id='type', ctx=Load()),
#       simple=1)])
# Dict(
#   keys=[
#     Constant(value='x'),
#     Constant(value=2)],
#   values=[
#     Name(id='int', ctx=Load()),
#     Name(id='bool', ctx=Load())])
# <class 'str'> x
# Name(id='int', ctx=Load())
# <class 'int'> 2

# %%
import ast

def process_class(test: str):
    cl = ast.parse(test)

    print("---\nWe have this:\n")
    print(cl.body[0])
    # print("---")
    # for f in list(cl.body[0].__dict__):
    #     print(f, ": ", getattr(cl.body[0], f))  # Print the body of the class to see the fields
    # print("---")
    print(cl.body[0].body)# Print the body of the class to see the fields
    print("---")
    # print each element in the body
    for b in cl.body[0].body:
        print(b)
    print("----")

test = """
class MyEnum[T,Y,U](GenericEnum):
    Variant1 = {"a": int, "b": str}
    Variant2 = {}
    Variant3 = {"x": float}

    def method(self: "MyEnum") -> None:
        pass
"""
process_class(test)
# Out:
# ---
# We have this:
#
# ClassDef(name='MyEnum', bases=[Name(id='GenericEnum', ctx=Load())], keywords=[], body=[Assign(targets=[Name(id='Variant1', ctx=Store(...))], value=Dict(keys=[Constant(...), Constant(...)], values=[Name(...), Name(...)]), type_comment=None), ..., FunctionDef(name='method', args=arguments(posonlyargs=[], args=[arg(...)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Pass()], decorator_list=[], returns=Constant(value=None, kind=None), type_comment=None, type_params=[])], decorator_list=[], type_params=[TypeVar(name='T', bound=None, default_value=None), ..., TypeVar(name='U', bound=None, default_value=None)])
# ...

# %%
import ast

test = """
class MyEnum:
    #'''This is a docstring for MyEnum'''
    Variant1 = {"a": int, "b": str}
    Variant2 = 10
    #Variant3, v4 = {"x": float}, {}
    #Variant4 = 42
    #Variant5: str = "hello"
    #def example_method(self: "MyEnum") -> str:
    #    return "example_method called"
    """

# Parse the test string
process_class(test)
# Out:
# ---
# We have this:
#
# ClassDef(name='MyEnum', bases=[], keywords=[], body=[Assign(targets=[Name(id='Variant1', ctx=Store(...))], value=Dict(keys=[Constant(...), Constant(...)], values=[Name(...), Name(...)]), type_comment=None), Assign(targets=[Name(id='Variant2', ctx=Store(...))], value=Constant(value=10, kind=None), type_comment=None)], decorator_list=[], type_params=[])
# [Assign(targets=[Name(id='Variant1', ctx=Store())], value=Dict(keys=[Constant(value='a', kind=None), Constant(value='b', kind=None)], values=[Name(id='int', ctx=Load(...)), Name(id='str', ctx=Load(...))]), type_comment=None), Assign(targets=[Name(id='Variant2', ctx=Store())], value=Constant(value=10, kind=None), type_comment=None)]
# ---
# Assign(targets=[Name(id='Variant1', ctx=Store())], value=Dict(keys=[Constant(value='a', kind=None), Constant(value='b', kind=None)], values=[Name(id='int', ctx=Load(...)), Name(id='str', ctx=Load(...))]), type_comment=None)
# ...

# %%
cls_node = ast.parse(test)
cls_def = cls_node.body[0]

print("Testing enum/struct body pattern matching:\n")
print(f"Total body nodes: {len(cls_def.body)}\n")

for i, node in enumerate(cls_def.body):
    print(f"Node {i}: {type(node).__name__}")
    match i, node:
        # TODO: do we allow `pass` statements to define empty enum?
        case _, ast.Pass():
            print("  -> Matched: Pass statement")

        # Docstrings are also fine if they occur at the start
        case 0, ast.Expr(value=ast.Constant(value=v)) if isinstance(v, str):
            print(f"  -> Matched: Docstring - '{node.value.value}'")

        # We do not allow methods, for now
        case _, ast.FunctionDef() as node:
            print(f"  -> Matched: Method definition - '{node.name}'")
            print(f"     This would raise UnsupportedError for enum definitions")

        # hereeeee
        # Struct fields are declared via annotated assignments without value
        case _, ast.Assign(targets=[ast.Name(id=field_name)],value=ast.Dict()) as node:
            print("Node: ", node)
            # print all the fields-value of the assignment
            for f in list(node.__dict__):
                print(f, ": ", getattr(node, f)) 
            

    
        # if unexpected statement are found
        case _, node:
            print(f"  -> Matched: Unexpected statement - {node}")
    print("---")


    print()
# Out:
# Testing enum/struct body pattern matching:
#
# Total body nodes: 2
#
# Node 0: Assign
# Node:  Assign(targets=[Name(id='Variant1', ctx=Store())], value=Dict(keys=[Constant(value='a', kind=None), Constant(value='b', kind=None)], values=[Name(id='int', ctx=Load(...)), Name(id='str', ctx=Load(...))]), type_comment=None)
# targets :  [Name(id='Variant1', ctx=Store())]
# value :  Dict(keys=[Constant(value='a', kind=None), Constant(value='b', kind=None)], values=[Name(id='int', ctx=Load()), Name(id='str', ctx=Load())])
# type_comment :  None
# lineno :  4
# col_offset :  4
# end_lineno :  4
# end_col_offset :  35
# ---
#
# Node 1: Assign
#   -> Matched: Unexpected statement - Assign(targets=[Name(id='Variant2', ctx=Store())], value=Constant(value=10, kind=None), type_comment=None)
# ---

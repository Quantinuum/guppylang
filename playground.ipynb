# %%
import ast

test = """


c = MyClass(10)
c.method(3.14)
"""
print(ast.dump(ast.parse(test), indent=2))
# Out:
# Module(
#   body=[
#     Assign(
#       targets=[
#         Name(id='c', ctx=Store())],
#       value=Call(
#         func=Name(id='MyClass', ctx=Load()),
#         args=[
#           Constant(value=10)])),
#     Expr(
#       value=Call(
#         func=Attribute(
#           value=Name(id='c', ctx=Load()),
#           attr='method',
#           ctx=Load()),
#         args=[
#           Constant(value=3.14)]))])

# %%
import guppylang
from guppylang import guppy

from typing import Counter

from guppylang import guppy
from guppylang.std.builtins import result, array, exit, panic
from guppylang.std.quantum import measure_array, measure, qubit, h, cx
from guppylang.defs import GuppyFunctionDefinition

from selene_sim import DepolarizingErrorModel
from selene_sim.exceptions import SelenePanicError

from guppylang.defs import GuppyFunctionDefinition
from guppylang.std.quantum import qubit, measure, h, cx


def run(main_def: GuppyFunctionDefinition) -> Counter:
    res = (
        main_def.emulator(n_qubits=8)
        .stabilizer_sim()
        .with_seed(42)
        .with_shots(1)
        .run()
    )

    return res.collated_counts()
# Out:
# Registering function:  swap , def id: DefId(id=23)
# Registering function:  take , def id: DefId(id=24)
# Registering function:  __iter__ , def id: DefId(id=54)
# Registering function:  __next__ , def id: DefId(id=55)
# Registering struct for class Range def id: DefId(id=56)
# 	Registered impl: __iter__ with id: DefId(id=54)
# 	Registered impl: __next__ with id: DefId(id=55)
# Registering function:  _range1 , def id: DefId(id=57)
# Registering function:  _range2 , def id: DefId(id=58)
# Registering function:  _range3 , def id: DefId(id=59)
# Registering function:  _range_comptime , def id: DefId(id=60)
# Registering function:  __len__ , def id: DefId(id=67)
# Registering function:  __iter__ , def id: DefId(id=69)
# Registering function:  try_take , def id: DefId(id=73)
# Registering function:  try_put , def id: DefId(id=75)
# Registering function:  __next__ , def id: DefId(id=76)
# Registering struct for class ArrayIter def id: DefId(id=77)
# 	Registered impl: __next__ with id: DefId(id=76)
# Registering function:  __len__ , def id: DefId(id=80)
# Registering function:  __iter__ , def id: DefId(id=81)
# Registering function:  mutable_copy , def id: DefId(id=82)
# Registering function:  __next__ , def id: DefId(id=83)
# Registering struct for class FrozenarrayIter def id: DefId(id=84)
# 	Registered impl: __next__ with id: DefId(id=83)
# Registering function:  __bool__ , def id: DefId(id=88)
# Registering function:  __truediv__ , def id: DefId(id=126)
# Registering function:  __bool__ , def id: DefId(id=132)
# Registering function:  __pow__ , def id: DefId(id=154)
# Registering function:  __truediv__ , def id: DefId(id=172)
# Registering function:  __bool__ , def id: DefId(id=177)
# Registering function:  __divmod__ , def id: DefId(id=179)
# Registering function:  __floordiv__ , def id: DefId(id=183)
# Registering function:  __mod__ , def id: DefId(id=189)
# Registering function:  __ne__ , def id: DefId(id=232)
# Registering function:  __int__ , def id: DefId(id=233)
# Registering function:  __nat__ , def id: DefId(id=234)
# Registering function:  __add__ , def id: DefId(id=248)
# Registering function:  __sub__ , def id: DefId(id=249)
# Registering function:  __mul__ , def id: DefId(id=250)
# Registering function:  __rmul__ , def id: DefId(id=251)
# Registering function:  __truediv__ , def id: DefId(id=252)
# Registering function:  __rtruediv__ , def id: DefId(id=253)
# Registering function:  __neg__ , def id: DefId(id=254)
# Registering function:  __float__ , def id: DefId(id=255)
# Registering function:  __eq__ , def id: DefId(id=256)
# Registering struct for class angle def id: DefId(id=257)
# 	Registered impl: __add__ with id: DefId(id=248)
# 	Registered impl: __sub__ with id: DefId(id=249)
# 	Registered impl: __mul__ with id: DefId(id=250)
# 	Registered impl: __rmul__ with id: DefId(id=251)
# 	Registered impl: __truediv__ with id: DefId(id=252)
# 	Registered impl: __rtruediv__ with id: DefId(id=253)
# 	Registered impl: __neg__ with id: DefId(id=254)
# 	Registered impl: __float__ with id: DefId(id=255)
# 	Registered impl: __eq__ with id: DefId(id=256)
# Registering function:  measure , def id: DefId(id=260)
# Registering function:  project_z , def id: DefId(id=261)
# Registering function:  discard , def id: DefId(id=262)
# Registering function:  measure_array , def id: DefId(id=288)
# Registering function:  discard_array , def id: DefId(id=289)
# Registering function:  ch , def id: DefId(id=290)

# %%
from guppylang.std.builtins import result
from numpy import single

@guppy.struct
class QubitSingle:
    q: int

    @guppy
    def __init__(self: "QubitSingle", q: int) -> None:
        self.q = q


@guppy.struct
class QubitPair:
    q1: int
    q2: int
    name: str

    @guppy
    def sum(self: "QubitPair", j: bool) -> None:
        pass


@guppy
def make_struct() -> None:
    pair = QubitPair(1, 2, "prova")
    pair.sum(True)
    single = QubitSingle(5)
#     return
#     # result("tag", pair.method())

# # run(make_struct)
g = make_struct.compile().modules[0]
# Out:
# Registering function:  __init__ , def id: DefId(id=351)
# Registering struct for class QubitSingle def id: DefId(id=352)
# 	Registered impl: __new__ with id: DefId(id=351)
# Registering function:  sum , def id: DefId(id=353)
# Registering struct for class QubitPair def id: DefId(id=354)
# 	Registered impl: sum with id: DefId(id=353)
# Registering function:  make_struct , def id: DefId(id=355)
# Compiling Guppy definition with id: DefId(id=355)
# >check_signature called:
# >£parsed function make_struct with type: () -> None
# 			+get_checked on definition for id: DefId(id=355)
# >check_global_func_def:
# 	func name: make_struct
# 	func args: [
# 	]
# 	func ty inputs: [
# 	]
# 	inputs: [
# 	]
# --------------------------
# >check_cfg for function make_struct...
# >synthesizing expr:
#    Call(
#   func=Name(id='QubitPair', ctx=Load()),
#   args=[
#     Constant(value=1),
#     Constant(value=2),
#     Constant(value='prova')])
# >visit_Call:
# % node:
#  Call(
#         func=Name(id='QubitPair', ctx=Load()),
#         args=[
#                 Constant(value=1),
#                 Constant(value=2),
#                 Constant(value='prova')])
# >synthesizing expr:
#    Name(id='QubitPair', ctx=Load())
# 			+get_checked on definition for id: DefId(id=354)
# --------------------------------
# Registering generated methods for struct QubitPair
# 	Registering method __new__ with id DefId(id=356)
# --------------------------------
# >synthesize_call:
# 	func_ty=(int, int, str) -> QubitPair,
# 	args=[Constant(value=1, kind=None), Constant(value=2, kind=None), Constant(value='prova', kind=None)],
# 	node=Call(func=GlobalName(id='QubitPair', def_id=DefId(id=356)), args=[Constant(value=1), Constant(value=2), Constant(value='prova')])
# 	custom_constructor=False
# >check_num_args: exp=3, act=3, node=Call(func=GlobalName(id='QubitPair', def_id=DefId(id=356)), args=[Constant(value=1), Constant(value=2), Constant(value='prova')]), coustom_constructor=False
# >check_num_args: exp=3, act=3, node=Call(func=GlobalName(id='QubitPair', def_id=DefId(id=356)), args=[Constant(value=1), Constant(value=2), Constant(value='prova')]), coustom_constructor=False
# >type_check_args:
#  func_ty.inputs: [FuncInput(ty=NumericType(kind=<Kind.Int: 2>), flags=<InputFlags.NoFlags: 0>, name='q1'), FuncInput(ty=NumericType(kind=<Kind.Int: 2>), flags=<InputFlags.NoFlags: 0>, name='q2'), FuncInput(ty=OpaqueType(args=[], defn=OpaqueTypeDef(id=DefId(id=8), name='str', defined_at=None, description='type', params=[], never_copyable=False, never_droppable=False, to_hugr=<function <lambda> at 0x133426cf0>, bound=None)), flags=<InputFlags.NoFlags: 0>, name='name')]
#  inputs: ['Constant(value=1)', 'Constant(value=2)', "Constant(value='prova')"]
# >synthesizing expr:
#    Call(
#   func=Attribute(
#     value=Name(id='pair', ctx=Load()),
#     attr='sum',
#     ctx=Load()),
#   args=[
#     Constant(value=True)])
# >visit_Call:
# % node:
#  Call(
#         func=Attribute(
#                 value=Name(id='pair', ctx=Load()),
#                 attr='sum',
#                 ctx=Load()),
#         args=[
#                 Constant(value=True)])
# >synthesizing expr:
#    Attribute(
#   value=Name(id='pair', ctx=Load()),
#   attr='sum',
#   ctx=Load())
# >synthesizing expr:
#    Name(id='pair', ctx=Load())
# 			+get_checked on definition for id: DefId(id=354)
# >check_signature called:
# 			+get_checked on definition for id: DefId(id=354)
# >£parsed function sum with type: (QubitPair, bool) -> None
# >visit_Call:
# % node:
#  Call(
#         func=GlobalName(id='sum', def_id=DefId(id=353)),
#         args=[
#                 PlaceNode(place=Variable(name='pair', ty=StructType(args=[], defn=CheckedStructDef(id=DefId(id=354), name='QubitPair', defined_at=ClassDef(name='QubitPair', bases=[], keywords=[], body=[AnnAssign(target=Name(id='q1', ctx=Store(...)), annotation=Name(id='int', ctx=Load(...)), value=None, simple=1), ..., FunctionDef(name='sum', args=arguments(posonlyargs=[], args=[arg(...), arg(...)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Pass()], decorator_list=[Name(id='guppy', ctx=Load(...))], returns=Constant(value=None, kind=None), type_comment=None, type_params=[])], decorator_list=[Attribute(value=Name(id='guppy', ctx=Load(...)), attr='struct', ctx=Load())], type_params=[]), description='type', params=[], fields=[StructField(name='q1', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='q2', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='name', ty=OpaqueType(args=[], defn=OpaqueTypeDef(id=DefId(id=8), name='str', defined_at=None, description='type', params=[], never_copyable=False, never_droppable=False, to_hugr=<function <lambda> at 0x133426cf0>, bound=None)))], constructor=None)), defined_at=Name(id='pair', ctx=Store()), flags=<InputFlags.NoFlags: 0>, is_func_input=False)),
#                 Constant(value=True)])
# >synthesizing expr:
#    GlobalName(id='sum', def_id=DefId(id=353))
# >typed from parsing:  (QubitPair, bool) -> None
# >synthesize_call:
# 	func_ty=(QubitPair, bool) -> None,
# 	args=[PlaceNode(place=Variable(name='pair', ty=StructType(args=[], defn=CheckedStructDef(id=DefId(id=354), name='QubitPair', defined_at=ClassDef(name='QubitPair', bases=[], keywords=[], body=[AnnAssign(target=Name(id='q1', ctx=Store(...)), annotation=Name(id='int', ctx=Load(...)), value=None, simple=1), ..., FunctionDef(name='sum', args=arguments(posonlyargs=[], args=[arg(...), arg(...)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Pass()], decorator_list=[Name(id='guppy', ctx=Load(...))], returns=Constant(value=None, kind=None), type_comment=None, type_params=[])], decorator_list=[Attribute(value=Name(id='guppy', ctx=Load(...)), attr='struct', ctx=Load())], type_params=[]), description='type', params=[], fields=[StructField(name='q1', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='q2', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='name', ty=OpaqueType(args=[], defn=OpaqueTypeDef(id=DefId(id=8), name='str', defined_at=None, description='type', params=[], never_copyable=False, never_droppable=False, to_hugr=<function <lambda> at 0x133426cf0>, bound=None)))], constructor=None)), defined_at=Name(id='pair', ctx=Store()), flags=<InputFlags.NoFlags: 0>, is_func_input=False)), Constant(value=True, kind=None)],
# 	node=Call(func=GlobalName(id='sum', def_id=DefId(id=353)), args=[PlaceNode(place=Variable(name='pair', ty=StructType(args=[], defn=CheckedStructDef(id=DefId(id=354), name='QubitPair', defined_at=ClassDef(name='QubitPair', bases=[], keywords=[], body=[AnnAssign(target=Name(id='q1', ctx=Store(...)), annotation=Name(id='int', ctx=Load(...)), value=None, simple=1), ..., FunctionDef(name='sum', args=arguments(posonlyargs=[], args=[arg(...), arg(...)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Pass()], decorator_list=[Name(id='guppy', ctx=Load(...))], returns=Constant(value=None, kind=None), type_comment=None, type_params=[])], decorator_list=[Attribute(value=Name(id='guppy', ctx=Load(...)), attr='struct', ctx=Load())], type_params=[]), description='type', params=[], fields=[StructField(name='q1', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='q2', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='name', ty=OpaqueType(args=[], defn=OpaqueTypeDef(id=DefId(id=8), name='str', defined_at=None, description='type', params=[], never_copyable=False, never_droppable=False, to_hugr=<function <lambda> at 0x133426cf0>, bound=None)))], constructor=None)), defined_at=Name(id='pair', ctx=Store()), flags=<InputFlags.NoFlags: 0>, is_func_input=False)), Constant(value=True)])
# 	custom_constructor=False
# >check_num_args: exp=2, act=2, node=Call(func=GlobalName(id='sum', def_id=DefId(id=353)), args=[PlaceNode(place=Variable(name='pair', ty=StructType(args=[], defn=CheckedStructDef(id=DefId(id=354), name='QubitPair', defined_at=ClassDef(name='QubitPair', bases=[], keywords=[], body=[AnnAssign(target=Name(id='q1', ctx=Store(...)), annotation=Name(id='int', ctx=Load(...)), value=None, simple=1), ..., FunctionDef(name='sum', args=arguments(posonlyargs=[], args=[arg(...), arg(...)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Pass()], decorator_list=[Name(id='guppy', ctx=Load(...))], returns=Constant(value=None, kind=None), type_comment=None, type_params=[])], decorator_list=[Attribute(value=Name(id='guppy', ctx=Load(...)), attr='struct', ctx=Load())], type_params=[]), description='type', params=[], fields=[StructField(name='q1', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='q2', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='name', ty=OpaqueType(args=[], defn=OpaqueTypeDef(id=DefId(id=8), name='str', defined_at=None, description='type', params=[], never_copyable=False, never_droppable=False, to_hugr=<function <lambda> at 0x133426cf0>, bound=None)))], constructor=None)), defined_at=Name(id='pair', ctx=Store()), flags=<InputFlags.NoFlags: 0>, is_func_input=False)), Constant(value=True)]), coustom_constructor=False
# >check_num_args: exp=2, act=2, node=Call(func=GlobalName(id='sum', def_id=DefId(id=353)), args=[PlaceNode(place=Variable(name='pair', ty=StructType(args=[], defn=CheckedStructDef(id=DefId(id=354), name='QubitPair', defined_at=ClassDef(name='QubitPair', bases=[], keywords=[], body=[AnnAssign(target=Name(id='q1', ctx=Store(...)), annotation=Name(id='int', ctx=Load(...)), value=None, simple=1), ..., FunctionDef(name='sum', args=arguments(posonlyargs=[], args=[arg(...), arg(...)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Pass()], decorator_list=[Name(id='guppy', ctx=Load(...))], returns=Constant(value=None, kind=None), type_comment=None, type_params=[])], decorator_list=[Attribute(value=Name(id='guppy', ctx=Load(...)), attr='struct', ctx=Load())], type_params=[]), description='type', params=[], fields=[StructField(name='q1', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='q2', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='name', ty=OpaqueType(args=[], defn=OpaqueTypeDef(id=DefId(id=8), name='str', defined_at=None, description='type', params=[], never_copyable=False, never_droppable=False, to_hugr=<function <lambda> at 0x133426cf0>, bound=None)))], constructor=None)), defined_at=Name(id='pair', ctx=Store()), flags=<InputFlags.NoFlags: 0>, is_func_input=False)), Constant(value=True)]), coustom_constructor=False
# >type_check_args:
#  func_ty.inputs: [FuncInput(ty=StructType(args=[], defn=CheckedStructDef(id=DefId(id=354), name='QubitPair', defined_at=ClassDef(name='QubitPair', bases=[], keywords=[], body=[AnnAssign(target=Name(id='q1', ctx=Store(...)), annotation=Name(id='int', ctx=Load(...)), value=None, simple=1), ..., FunctionDef(name='sum', args=arguments(posonlyargs=[], args=[arg(...), arg(...)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Pass()], decorator_list=[Name(id='guppy', ctx=Load(...))], returns=Constant(value=None, kind=None), type_comment=None, type_params=[])], decorator_list=[Attribute(value=Name(id='guppy', ctx=Load(...)), attr='struct', ctx=Load())], type_params=[]), description='type', params=[], fields=[StructField(name='q1', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='q2', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='name', ty=OpaqueType(args=[], defn=OpaqueTypeDef(id=DefId(id=8), name='str', defined_at=None, description='type', params=[], never_copyable=False, never_droppable=False, to_hugr=<function <lambda> at 0x133426cf0>, bound=None)))], constructor=None)), flags=<InputFlags.NoFlags: 0>, name='self'), FuncInput(ty=OpaqueType(args=[], defn=OpaqueTypeDef(id=DefId(id=4), name='bool', defined_at=None, description='type', params=[], never_copyable=False, never_droppable=False, to_hugr=<function <lambda> at 0x133426c40>, bound=None)), flags=<InputFlags.NoFlags: 0>, name='j')]
#  inputs: ["PlaceNode(place=Variable(name='pair', ty=StructType(args=[], defn=CheckedStructDef(id=DefId(id=354), name='QubitPair', defined_at=ClassDef(name='QubitPair', bases=[], keywords=[], body=[AnnAssign(target=Name(id='q1', ctx=Store(...)), annotation=Name(id='int', ctx=Load(...)), value=None, simple=1), ..., FunctionDef(name='sum', args=arguments(posonlyargs=[], args=[arg(...), arg(...)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Pass()], decorator_list=[Name(id='guppy', ctx=Load(...))], returns=Constant(value=None, kind=None), type_comment=None, type_params=[])], decorator_list=[Attribute(value=Name(id='guppy', ctx=Load(...)), attr='struct', ctx=Load())], type_params=[]), description='type', params=[], fields=[StructField(name='q1', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='q2', ty=NumericType(kind=<Kind.Int: 2>)), StructField(name='name', ty=OpaqueType(args=[], defn=OpaqueTypeDef(id=DefId(id=8), name='str', defined_at=None, description='type', params=[], never_copyable=False, never_droppable=False, to_hugr=<function <lambda> at 0x133426cf0>, bound=None)))], constructor=None)), defined_at=Name(id='pair', ctx=Store()), flags=<InputFlags.NoFlags: 0>, is_func_input=False))", 'Constant(value=True)']
# >synthesizing expr:
#    Call(
#   func=Name(id='QubitSingle', ctx=Load()),
#   args=[
#     Constant(value=5)])
# >visit_Call:
# % node:
#  Call(
#         func=Name(id='QubitSingle', ctx=Load()),
#         args=[
#                 Constant(value=5)])
# >synthesizing expr:
#    Name(id='QubitSingle', ctx=Load())
# 			+get_checked on definition for id: DefId(id=352)
# --------------------------------
# Registering generated methods for struct QubitSingle
# --------------------------------
# >check_signature called:
# 			+get_checked on definition for id: DefId(id=352)
# >£parsed function __new__ with type: (QubitSingle, int) -> None
# >typed from parsing:  (QubitSingle, int) -> None
# >synthesize_call:
# 	func_ty=(QubitSingle, int) -> None,
# 	args=[Constant(value=5, kind=None)],
# 	node=Call(func=GlobalName(id='QubitSingle', def_id=DefId(id=351)), args=[Constant(value=5)])
# 	custom_constructor=True
# >check_num_args: exp=2, act=1, node=Call(func=GlobalName(id='QubitSingle', def_id=DefId(id=351)), args=[Constant(value=5)]), coustom_constructor=True
# >check_num_args: exp=2, act=1, node=Call(func=GlobalName(id='QubitSingle', def_id=DefId(id=351)), args=[Constant(value=5)]), coustom_constructor=True
# >type_check_args:
#  func_ty.inputs: [FuncInput(ty=StructType(args=[], defn=CheckedStructDef(id=DefId(id=352), name='QubitSingle', defined_at=ClassDef(name='QubitSingle', bases=[], keywords=[], body=[AnnAssign(target=Name(id='q', ctx=Store(...)), annotation=Name(id='int', ctx=Load(...)), value=None, simple=1), FunctionDef(name='__init__', args=arguments(posonlyargs=[], args=[arg(...), arg(...)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Assign(targets=[Attribute(...)], value=Name(...), type_comment=None)], decorator_list=[Name(id='guppy', ctx=Load(...))], returns=Constant(value=None, kind=None), type_comment=None, type_params=[])], decorator_list=[Attribute(value=Name(id='guppy', ctx=Load(...)), attr='struct', ctx=Load())], type_params=[]), description='type', params=[], fields=[StructField(name='q', ty=NumericType(kind=<Kind.Int: 2>))], constructor=FunctionDef(name='__init__', args=arguments(posonlyargs=[], args=[arg(arg='self', annotation=Constant(...), type_comment=None), arg(arg='q', annotation=Name(...), type_comment=None)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Assign(targets=[Attribute(value=Name(...), attr='q', ctx=Store(...))], value=Name(id='q', ctx=Load(...)), type_comment=None)], decorator_list=[Name(id='guppy', ctx=Load())], returns=Constant(value=None, kind=None), type_comment=None, type_params=[]))), flags=<InputFlags.NoFlags: 0>, name='self'), FuncInput(ty=NumericType(kind=<Kind.Int: 2>), flags=<InputFlags.NoFlags: 0>, name='q')]
#  inputs: ['Constant(value=5)']
# 			+get_checked on definition for id: DefId(id=352)
# 			+get_checked on definition for id: DefId(id=4)
# 			+get_checked on definition for id: DefId(id=8)
# 			+get_checked on definition for id: DefId(id=6)
# 			+get_checked on definition for id: DefId(id=354)
# 			+get_checked on definition for id: DefId(id=351)
# >check_global_func_def:
# 	func name: __init__
# 	func args: [
# 		 arg(
#     arg='self',
#     annotation=Constant(value='QubitSingle'))
# 		 arg(
#     arg='q',
#     annotation=Name(id='int', ctx=Load()))
# 	]
# 	func ty inputs: [
# 		 FuncInput(ty=StructType(args=[], defn=CheckedStructDef(id=DefId(id=352), name='QubitSingle', defined_at=ClassDef(name='QubitSingle', bases=[], keywords=[], body=[AnnAssign(target=Name(id='q', ctx=Store(...)), annotation=Name(id='int', ctx=Load(...)), value=None, simple=1), FunctionDef(name='__init__', args=arguments(posonlyargs=[], args=[arg(...), arg(...)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Assign(targets=[Attribute(...)], value=Name(...), type_comment=None)], decorator_list=[Name(id='guppy', ctx=Load(...))], returns=Constant(value=None, kind=None), type_comment=None, type_params=[])], decorator_list=[Attribute(value=Name(id='guppy', ctx=Load(...)), attr='struct', ctx=Load())], type_params=[]), description='type', params=[], fields=[StructField(name='q', ty=NumericType(kind=<Kind.Int: 2>))], constructor=FunctionDef(name='__init__', args=arguments(posonlyargs=[], args=[arg(arg='self', annotation=Constant(...), type_comment=None), arg(arg='q', annotation=Name(...), type_comment=None)], vararg=None, kwonlyargs=[], kw_defaults=[], kwarg=None, defaults=[]), body=[Assign(targets=[Attribute(value=Name(...), attr='q', ctx=Store(...))], value=Name(id='q', ctx=Load(...)), type_comment=None)], decorator_list=[Name(id='guppy', ctx=Load())], returns=Constant(value=None, kind=None), type_comment=None, type_params=[]))), flags=<InputFlags.NoFlags: 0>, name='self')
# 		 FuncInput(ty=NumericType(kind=<Kind.Int: 2>), flags=<InputFlags.NoFlags: 0>, name='q')
# 	]
# 	inputs: [
# 		 self
# 		 q
# 	]
# --------------------------
# >check_cfg for function __init__...
# >synthesizing expr:
#    Name(id='q', ctx=Load())
# > _check_field_assign
#  lhs: Attribute(
#   value=Name(id='self', ctx=Load()),
#   attr='q',
#   ctx=Store())
#  rhs_ty: int
# >synthesizing expr:
#    Name(id='self', ctx=Load())
# Traceback (most recent call last):
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/.devenv/state/venv/lib/python3.14/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/sx/bbzfd6mn5txdvh5bghnjgp5m0000gp/T/ipykernel_77099/4168177058.py", line 33, in <module>
#     g = make_struct.compile().modules[0]
#         ~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang/src/guppylang/defs.py", line 158, in compile
#     return self.compile_entrypoint()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/error.py", line 107, in pretty_errors_wrapped
#     return f(*args, **kwargs)
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang/src/guppylang/defs.py", line 171, in compile_entrypoint
#     pack = self.compile_function()
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang/src/guppylang/defs.py", line 204, in compile_function
#     return super().compile()
#            ~~~~~~~~~~~~~~~^^
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang/src/guppylang/defs.py", line 75, in compile
#     package: Package = ENGINE.compile(self.id).package
#                        ~~~~~~~~~~~~~~^^^^^^^^^
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/error.py", line 107, in pretty_errors_wrapped
#     return f(*args, **kwargs)
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/engine.py", line 251, in compile
#     self.check(id)
#     ~~~~~~~~~~^^^^
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/error.py", line 107, in pretty_errors_wrapped
#     return f(*args, **kwargs)
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/engine.py", line 243, in check
#     self.checked[id] = self.get_checked(id)
#                        ~~~~~~~~~~~~~~~~^^^^
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/error.py", line 107, in pretty_errors_wrapped
#     return f(*args, **kwargs)
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/engine.py", line 206, in get_checked
#     defn = defn.check(Globals(DEF_STORE.frames[defn.id]))
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/definition/function.py", line 122, in check
#     cfg = check_global_func_def(self.defined_at, self.ty, globals)
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/checker/func_checker.py", line 185, in check_global_func_def
#     return check_cfg(cfg, inputs, ty.output, generic_params, func_def.name, globals)
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/checker/cfg_checker.py", line 96, in check_cfg
#     checked_cfg.entry_bb = check_bb(
#                            ~~~~~~~~^
#         cfg.entry_bb, checked_cfg, inputs, return_ty, generic_params, globals
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/checker/cfg_checker.py", line 231, in check_bb
#     checked_stmts = StmtChecker(ctx, bb, return_ty).check_stmts(bb.statements)
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/checker/stmt_checker.py", line 108, in check_stmts
#     return [self.visit(s) for s in stmts]
#             ~~~~~~~~~~^^^
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/ast_util.py", line 53, in visit
#     return visitor(node, *args, **kwargs)
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/checker/stmt_checker.py", line 362, in visit_Assign
#     node.targets = [self._check_assign(target, node.value, ty)]
#                     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/nix/store/1mh1a0kzkd1jdbay2bmpf2wj7r1hl3bb-python3-3.14.0-env/lib/python3.14/functools.py", line 1070, in __call__
#     return self._dispatch(args[0].__class__).__get__(self._obj, self._cls)(*args, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/nicola.assolini/Documents/GitHub/guppylang/guppylang-internals/src/guppylang_internals/checker/stmt_checker.py", line 178, in _check_field_assign
#     raise GuppyError(
#     ...<3 lines>...
#     )
# guppylang_internals.error.GuppyError: UnsupportedError(span=Span(start=Loc(file='/var/folders/sx/bbzfd6mn5txdvh5bghnjgp5m0000gp/T/ipykernel_77099/4168177058.py', line=10, column=13), end=Loc(file='/var/folders/sx/bbzfd6mn5txdvh5bghnjgp5m0000gp/T/ipykernel_77099/4168177058.py', line=10, column=14)), _parent=None, children=[], things='Mutation of classical fields', singular=True, unsupported_in='')

# %%
# Set Graphviz executable path for devenv
# import os
# os.environ["PATH"] = "/nix/store/8n76jy6632p7z6w6lq530aghrp7fpbrx-graphviz-12.2.1/bin:" + os.environ.get("PATH", "")
# g.render_dot()

# from tket.circuit import Tk2Circuit
# print(Tk2Circuit.from_bytes(g.to_bytes()).render_mermaid())

# %%
from guppylang.std.quantum import cx
from guppylang import guppy, qubit
from guppylang.std.builtins import array


@guppy
def main() -> None:
    arr: array[qubit, 2] = array(qubit() for _ in range(2))

    # Do this at least 97 times, you should still get the same drop violation message
    # This is a regression test for https://github.com/Quantinuum/guppylang/issues/1404.
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])
    cx(arr[0], arr[1])


main.compile()
# Out:
# Error: Drop violation (at <In[1]>:7:4)
#   |
# 5 | @guppy
# 6 | def main() -> None:
# 7 |     arr: array[qubit, 2] = array(qubit() for _ in range(2))
#   |     ^^^ Variable `arr` with non-droppable type `array[qubit, 2]` is
#   |         leaked
#
# Help: Make sure that `arr` is consumed or returned to avoid the leak
#
# Guppy compilation failed due to 1 previous error
